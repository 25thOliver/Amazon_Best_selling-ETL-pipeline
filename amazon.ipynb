# %% [markdown]
# ## Amazon Bestseller ETL Pipeline

# %%
import pandas as pd
import requests
import time

# %% [markdown]
# ### Step 1: Extract - Getting the Data from API

# %%
# Extract data from API
api_url = "https://data-liart.vercel.app/data"
response = requests.get(api_url)
data = response.json()

# %%
# Convert to DataFrame
amazon_df = pd.DataFrame(data['data'])

# %%
# Basic info about the data
amazon_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           999 non-null    int64
#  1   rank                 999 non-null    int64
#  2   asin                 999 non-null    object
#  3   product_title        999 non-null    object
#  4   product_price        945 non-null    object
#  5   product_star_rating  969 non-null    float64
#  6   product_num_ratings  969 non-null    float64
#  7   product_url          999 non-null    object
#  8   product_photo        999 non-null    object
#  9   rank_change_label    0 non-null      object
#  10  country              999 non-null    object
#  11  page                 999 non-null    int64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 93.8+ KB

# %%
amazon_df.shape
# Out:
# (999, 12)

# %%
amazon_df.isnull().sum()
# Out:
# Unnamed: 0               0
# rank                     0
# asin                     0
# product_title            0
# product_price           54
# product_star_rating     30
# product_num_ratings     30
# product_url              0
# product_photo            0
# rank_change_label      999
# country                  0
# page                     0
# dtype: int64

# %%
# Extract all data with pagination
def fetch_all_data():
    all_data = []
    page = 1

    while True:
        response = requests.get(f"https://data-liart.vercel.app/data?page={page}")
        data = response.json()

        if not data.get('data'):
            break

        all_data.extend(data['data'])
        page += 1
        time.sleep(0.5)

        if page > 10:
            break
    return all_data

# %%
# Extract all data
all_data = fetch_all_data()
amazon_df = pd.DataFrame(all_data)

# %%
all_data
# Out:
# [{'Unnamed: 0': 0,
#   'rank': 1,
#   'asin': 'B073VKKNN9',
#   'product_title': 'Kaspersky | Premium - Total Security (Ultimate Security) | 1 Device | 1 Year | Email Delivery in 1 Hour',
#   'product_price': '₹469.00',
#   'product_star_rating': 4.3,
#   'product_num_ratings': 13324.0,
#   'product_url': 'https://www.amazon.in/dp/B073VKKNN9',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/71wvxMSor0L._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 1,
#   'rank': 2,
#   'asin': 'B07PQZJ6Y8',
#   'product_title': 'K7 Security K7, Total Security, 1 User, 1 Year, Email Delivery In 30 Min, No Cd',
#   'product_price': '₹370.00',
#   'product_star_rating': 4.4,
#   'product_num_ratings': 2291.0,
#   'product_url': 'https://www.amazon.in/dp/B07PQZJ6Y8',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/51HB079HbPS._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 2,
#   'rank': 3,
#   'asin': 'B0D1KL34JM',
#   'product_title': 'Microsoft Office 2021 Professional - Lifetime Validity - Windows only - Email delivery in 2 Hours- no CD - Email Bind Key',
#   'product_price': '₹1,799.00',
#   'product_star_rating': 4.5,
#   'product_num_ratings': 388.0,
#   'product_url': 'https://www.amazon.in/dp/B0D1KL34JM',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/51kuNOifu-L._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 3,
#   'rank': 4,
#   'asin': 'B07B9YYLGG',
#   'product_title': 'Bitdefender - 1 Device,1 Year - Mobile Security | Android| Latest Version | Email Delivery In 2 Hours- No Cd |',
#   'product_price': '₹94.00',
#   'product_star_rating': 4.1,
#   'product_num_ratings': 9630.0,
#   'product_url': 'https://www.amazon.in/dp/B07B9YYLGG',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/81lZybDFjpL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 4,
#   'rank': 5,
#   'asin': 'B073VLGMZ4',
#   'product_title': 'McAfee Total Protection 2025 | 1 Device, 3 Years | Antivirus Internet Security Software | Scam Protection & Identity Monitori',
#   'product_price': '₹1,699.00',
#   'product_star_rating': 4.4,
#   'product_num_ratings': 5783.0,
#   'product_url': 'https://www.amazon.in/dp/B073VLGMZ4',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/51WS+IgtDKL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 5,
#   'rank': 6,
#   'asin': 'B073VLNGJW',
#   'product_title': 'Bitdefender - 1 Computer,3 Years - Total Security | Windows | Latest Version | Email Delivery In 2 Hours- No Cd |',
#   'product_price': '₹599.00',
#   'product_star_rating': 4.4,
#   'product_num_ratings': 12973.0,
#   'product_url': 'https://www.amazon.in/dp/B073VLNGJW',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/81JA0Rnl38L._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 6,
#   'rank': 7,
#   'asin': 'B0CMJBCHQR',
#   'product_title': 'Microsoft Office 2019 Professional - Lifetime Validity - Windows only - Email delivery in 2 Hours- no CD',
#   'product_price': '₹1,199.00',
#   'product_star_rating': 4.3,
#   'product_num_ratings': 1080.0,
#   'product_url': 'https://www.amazon.in/dp/B0CMJBCHQR',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/317r8dRWUgL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 7,
#   'rank': 8,
#   'asin': 'B073VKKNND',
#   'product_title': 'McAfee Total Protection 2025 | 1 Device, 1 Year | Antivirus Internet Security Software | Scam Protection & Identity Monitorin',
#   'product_price': '₹745.00',
#   'product_star_rating': 4.1,
#   'product_num_ratings': 7588.0,
#   'product_url': 'https://www.amazon.in/dp/B073VKKNND',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/61a8KDc+otL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 8,
#   'rank': 9,
#   'asin': 'B09J52ZMNV',
#   'product_title': 'Apple - App Store Code - For India - Delivered via Email',
#   'product_price': '₹5,000.00',
#   'product_star_rating': 3.6,
#   'product_num_ratings': 279.0,
#   'product_url': 'https://www.amazon.in/dp/B09J52ZMNV',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/31uSyIDu8yL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 9,
#   'rank': 10,
#   'asin': 'B0F2F12QLT',
#   'product_title': 'Bitdefender 1 User, 3 Years- Total Security | Windows Latest Version | (Single Activation Code)- [Email Delivery in 2 hours -',
#   'product_price': '₹599.00',
#   'product_star_rating': 4.5,
#   'product_num_ratings': 84.0,
#   'product_url': 'https://www.amazon.in/dp/B0F2F12QLT',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/81s2ZQrBiRL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 10,
#   'rank': 11,
#   'asin': 'B073VMC9S4',
#   'product_title': 'Kaspersky | Total Security (Plus) | 1 Device | 3 Years | Email Delivery in 1 Hour',
#   'product_price': '₹999.00',
#   'product_star_rating': 4.4,
#   'product_num_ratings': 8075.0,
#   'product_url': 'https://www.amazon.in/dp/B073VMC9S4',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/61qiv6rgc-L._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 11,
#   'rank': 12,
#   'asin': 'B07C24N3MB',
#   'product_title': 'K7 Security K7 Antivirus Premium- 1 User, 1 Year (Email Delivery In 2 Hours, No Cd)',
#   'product_price': '₹225.00',
#   'product_star_rating': 4.2,
#   'product_num_ratings': 4631.0,
#   'product_url': 'https://www.amazon.in/dp/B07C24N3MB',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/61oh9Mc4UIL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 12,
#   'rank': 13,
#   'asin': 'B073VJYGYW',
#   'product_title': 'McAfee Antivirus 2024 | 1 Device, 1 Year | Antivirus Internet Security Software| Email Delivery',
#   'product_price': '₹399.00',
#   'product_star_rating': 4.1,
#   'product_num_ratings': 17965.0,
#   'product_url': 'https://www.amazon.in/dp/B073VJYGYW',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/616Ch24-LsL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 13,
#   'rank': 14,
#   'asin': 'B0DMNS2241',
#   'product_title': 'Quick Heal | Antivirus Pro | 1 user | 1 Year | AI Based Device Security for Laptop | Email and Browsing Protection| (Email De',
#   'product_price': '₹454.00',
#   'product_star_rating': 4.2,
#   'product_num_ratings': 239.0,
#   'product_url': 'https://www.amazon.in/dp/B0DMNS2241',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/61lIvRJCpIL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 14,
#   'rank': 15,
#   'asin': 'B07895T7B1',
#   'product_title': 'McAfee Antivirus 2024 | 1 Device, 3 Year | Antivirus Internet Security Software | Email Delivery',
#   'product_price': '₹750.00',
#   'product_star_rating': 4.2,
#   'product_num_ratings': 16839.0,
#   'product_url': 'https://www.amazon.in/dp/B07895T7B1',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/61Qu9ZaC+sL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 15,
#   'rank': 16,
#   'asin': 'B0FK5X2L2L',
#   'product_title': 'Win 11/10 Pro Lifetime Activation Retail License Product Key (1 Device, 32/64 Bit) | Permanent Activation | Reinstallation Su',
#   'product_price': '₹899.00',
#   'product_star_rating': 4.2,
#   'product_num_ratings': 18.0,
#   'product_url': 'https://www.amazon.in/dp/B0FK5X2L2L',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/61GnE-vZiDL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 16,
#   'rank': 17,
#   'asin': 'B08B1SL726',
#   'product_title': 'Kaspersky | Anti-Virus | 1 Device | 1 Year | Email Delivery in 1 Hour',
#   'product_price': '₹301.00',
#   'product_star_rating': 4.2,
#   'product_num_ratings': 4470.0,
#   'product_url': 'https://www.amazon.in/dp/B08B1SL726',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/61y-1+9ZdCL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 17,
#   'rank': 18,
#   'asin': 'B073VKKNN7',
#   'product_title': 'Quick Heal | Total Security Renewal Upgrade Gold pack | 1 User | 3 years | Email Delivery in 1 Hour - no CD| Existing Quick H',
#   'product_price': '₹1,869.00',
#   'product_star_rating': 4.4,
#   'product_num_ratings': 8418.0,
#   'product_url': 'https://www.amazon.in/dp/B073VKKNN7',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/61KXWWZ1L-L._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 18,
#   'rank': 19,
#   'asin': 'B07CBWJHJZ',
#   'product_title': "K7 Total Security - 1 PC's, 3 Years (Email Delivery in 2 hours - No CD)",
#   'product_price': '₹725.00',
#   'product_star_rating': 4.4,
#   'product_num_ratings': 2402.0,
#   'product_url': 'https://www.amazon.in/dp/B07CBWJHJZ',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/51Naj0jsuZL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 19,
#   'rank': 20,
#   'asin': 'B073VLGMYZ',
#   'product_title': 'Kaspersky Internet Security for Android Mobile Latest Version- 1 Device, 1 Year (Email Delivery in 1 Hour)',
#   'product_price': '₹199.00',
#   'product_star_rating': 4.2,
#   'product_num_ratings': 11906.0,
#   'product_url': 'https://www.amazon.in/dp/B073VLGMYZ',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/618S5Pqxi0L._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 20,
#   'rank': 21,
#   'asin': 'B073VJVSCC',
#   'product_title': 'Bitdefender - 1 Computer,1 Year - Total Security | Windows | Latest Version | Email Delivery In 2 Hours- No Cd |',
#   'product_price': '₹320.00',
#   'product_star_rating': 4.4,
#   'product_num_ratings': 12973.0,
#   'product_url': 'https://www.amazon.in/dp/B073VJVSCC',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/81+KsLxJa2L._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 21,
#   'rank': 22,
#   'asin': 'B08C85B28L',
#   'product_title': 'Microsoft 365 Personal -1 TB of cloud storage - Advanced security - Innovative apps with AI - 12-Month Subscription - Windows',
#   'product_price': '₹5,599.00',
#   'product_star_rating': 4.4,
#   'product_num_ratings': 2617.0,
#   'product_url': 'https://www.amazon.in/dp/B08C85B28L',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/51lb3P0hIPL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 22,
#   'rank': 23,
#   'asin': 'B0CDPG65DT',
#   'product_title': 'BitDefender Total Security Latest Version (Windows / Mac / Android / iOS) - 3 Devices, 3 Years (Single Activation Code) (Emai',
#   'product_price': '₹898.00',
#   'product_star_rating': 4.6,
#   'product_num_ratings': 704.0,
#   'product_url': 'https://www.amazon.in/dp/B0CDPG65DT',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/71fX9xvoLxL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 23,
#   'rank': 24,
#   'asin': 'B075S4HJMY',
#   'product_title': 'McAfee Total Protection 2025 | 1 Device, 3 Years | Antivirus Internet Security Software | Scam Protection & Identity Monitori',
#   'product_price': '₹1,699.00',
#   'product_star_rating': 4.4,
#   'product_num_ratings': 1253.0,
#   'product_url': 'https://www.amazon.in/dp/B075S4HJMY',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/51rSvnGsJzL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 24,
#   'rank': 25,
#   'asin': 'B073VJYGYZ',
#   'product_title': 'Bitdefender - 1 Computer,1 Year - Antivirus Plus | Windows | Latest Version | Email Delivery In 2 Hours- No Cd |',
#   'product_price': '₹149.00',
#   'product_star_rating': 4.0,
#   'product_num_ratings': 2009.0,
#   'product_url': 'https://www.amazon.in/dp/B073VJYGYZ',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/810tg5PrmJS._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 25,
#   'rank': 26,
#   'asin': 'B08B1SD2HZ',
#   'product_title': 'Kaspersky | Total Security | 1 Device | 1 Year | Email Delivery in 1 Hour',
#   'product_price': '₹469.00',
#   'product_star_rating': 4.3,
#   'product_num_ratings': 9953.0,
#   'product_url': 'https://www.amazon.in/dp/B08B1SD2HZ',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/61ykGuyH5DL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 26,
#   'rank': 27,
#   'asin': 'B08L7GCBG1',
#   'product_title': 'Kaspersky | Premium - Total Security (Ultimate Security) | 1 Device | 2 Years | Email Delivery in 1 Hour',
#   'product_price': '₹749.00',
#   'product_star_rating': 4.6,
#   'product_num_ratings': 820.0,
#   'product_url': 'https://www.amazon.in/dp/B08L7GCBG1',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/71wvxMSor0L._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 27,
#   'rank': 28,
#   'asin': 'B073VMC9RZ',
#   'product_title': 'Quick Heal | Total Security | 1 User | 3 Years | AI Based Device Security for PC | Banking Protection | Parental Control| (Em',
#   'product_price': '₹2,292.00',
#   'product_star_rating': 4.4,
#   'product_num_ratings': 14912.0,
#   'product_url': 'https://www.amazon.in/dp/B073VMC9RZ',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/61y2a2G3bXL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 28,
#   'rank': 29,
#   'asin': 'B0FK3TJ1CG',
#   'product_title': 'Ms 365 Professional Plus with Copilot Ai | Exclusive 2026 Edition | (5 Devices, Lifetime Validity) for Win, iOS, macOS, iPADO',
#   'product_price': '₹2,199.00',
#   'product_star_rating': 5.0,
#   'product_num_ratings': 4.0,
#   'product_url': 'https://www.amazon.in/dp/B0FK3TJ1CG',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/71guKi9QWDL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 29,
#   'rank': 30,
#   'asin': 'B0C5XBG24H',
#   'product_title': 'Kaspersky | Internet Security | 1 Device | 2 Years | Email Delivery in 1 Hour',
#   'product_price': '₹500.00',
#   'product_star_rating': 4.4,
#   'product_num_ratings': 442.0,
#   'product_url': 'https://www.amazon.in/dp/B0C5XBG24H',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/61yk38icANL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 30,
#   'rank': 31,
#   'asin': 'B073VL49H8',
#   'product_title': 'Quick Heal | Total Security | 1 User | 1 Year | AI Based Device Security for Windows PC | Banking and Browsing Protection | D',
#   'product_price': '₹1,182.00',
#   'product_star_rating': 4.4,
#   'product_num_ratings': 14912.0,
#   'product_url': 'https://www.amazon.in/dp/B073VL49H8',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/61pok8CXslL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 31,
#   'rank': 32,
#   'asin': 'B08C858V16',
#   'product_title': 'Microsoft 365 Family – 6 Devices- up to 6 TB of cloud storage (1 TB per person)- Advanced security - Innovative apps with AI ',
#   'product_price': '₹7,299.00',
#   'product_star_rating': 4.3,
#   'product_num_ratings': 4923.0,
#   'product_url': 'https://www.amazon.in/dp/B08C858V16',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/51eITIFJzaL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 32,
#   'rank': 33,
#   'asin': 'B07B8NHL2S',
#   'product_title': 'Bitdefender - 3 Computer,3 Years - Total Security | Windows | Latest Version | (Single Activation Code) Email Delivery in 2 H',
#   'product_price': '₹898.00',
#   'product_star_rating': 4.4,
#   'product_num_ratings': 12973.0,
#   'product_url': 'https://www.amazon.in/dp/B07B8NHL2S',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/81dKXrOXm6L._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 33,
#   'rank': 34,
#   'asin': 'B073VKTK96',
#   'product_title': 'Quick Heal | Total Security | 2 Users | 3 Years | AI Based Device Security for Windows PC | Banking and Browsing Protection |',
#   'product_price': '₹2,869.00',
#   'product_star_rating': 4.4,
#   'product_num_ratings': 14912.0,
#   'product_url': 'https://www.amazon.in/dp/B073VKTK96',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/610lPg9hOAL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 34,
#   'rank': 35,
#   'asin': 'B073VMC9RY',
#   'product_title': 'Quick Heal | Antivirus Pro | 1 user | 1 Year | AI Based Device Security for Laptop | Email and Browsing Protection (Email Del',
#   'product_price': '₹454.00',
#   'product_star_rating': 4.3,
#   'product_num_ratings': 12850.0,
#   'product_url': 'https://www.amazon.in/dp/B073VMC9RY',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/61enqjIAiGL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 35,
#   'rank': 36,
#   'asin': 'B073VJYFNJ',
#   'product_title': 'Quick Heal Total Security Renewal Upgrade Silver Pack - 1 User, 1 Year (Email Delivery In 1 Hour- No Cd) Existing Single User',
#   'product_price': '₹939.00',
#   'product_star_rating': 4.4,
#   'product_num_ratings': 8418.0,
#   'product_url': 'https://www.amazon.in/dp/B073VJYFNJ',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/61qEUJgAdXL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 36,
#   'rank': 37,
#   'asin': 'B0846J7XJ9',
#   'product_title': 'Net Protector NPAV Net Protector 2025 Total Security Gold Edition - 1 PC, 1 Year - (Email Delivery in 1 Hour - No CD)',
#   'product_price': '₹398.00',
#   'product_star_rating': 4.2,
#   'product_num_ratings': 1207.0,
#   'product_url': 'https://www.amazon.in/dp/B0846J7XJ9',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/51Wk8qnBJ+L._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 37,
#   'rank': 38,
#   'asin': 'B0C3W3CJPR',
#   'product_title': 'Kaspersky | Premium - Total Security (Ultimate Security) | 1 Device | 3 Years | Email Delivery in 1 Hour',
#   'product_price': '₹1,299.00',
#   'product_star_rating': 4.6,
#   'product_num_ratings': 406.0,
#   'product_url': 'https://www.amazon.in/dp/B0C3W3CJPR',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/71wvxMSor0L._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 38,
#   'rank': 39,
#   'asin': 'B0FK3F973M',
#   'product_title': 'MS Professional Plus LTSC 2024 (Complete Suite) | NEW 2025 Released | Retail License Key for Windows 10/11 (1 User/PC, Lifeti',
#   'product_price': '₹1,999.00',
#   'product_star_rating': 4.4,
#   'product_num_ratings': 11.0,
#   'product_url': 'https://www.amazon.in/dp/B0FK3F973M',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/61qsg3jGiDL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 39,
#   'rank': 40,
#   'asin': 'B081HKDDQW',
#   'product_title': 'Quick Heal | Antivirus Pro – Renewal Pack | 1 user | 3 Years | Email Delivery in 1 Hour - no CD | Existing Quick Heal Single ',
#   'product_price': '₹839.00',
#   'product_star_rating': 4.3,
#   'product_num_ratings': 3593.0,
#   'product_url': 'https://www.amazon.in/dp/B081HKDDQW',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/61UNonG582L._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 40,
#   'rank': 41,
#   'asin': 'B08B1RS45K',
#   'product_title': 'Kaspersky | Premium - Total Security (Ultimate Security) | 3 Devices | 1 Year | Email Delivery in 1 Hour',
#   'product_price': '₹799.00',
#   'product_star_rating': 4.3,
#   'product_num_ratings': 353.0,
#   'product_url': 'https://www.amazon.in/dp/B08B1RS45K',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/71wvxMSor0L._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 41,
#   'rank': 42,
#   'asin': 'B0FKP8NZCM',
#   'product_title': 'Ms Pro Plus LTSC 2024 Full Edition (100% Genuine) (New 2025 Updated) Lifetime Retail Key for Win (1 PC/User) | Reinstall Anyt',
#   'product_price': '₹1,999.00',
#   'product_star_rating': 3.4,
#   'product_num_ratings': 6.0,
#   'product_url': 'https://www.amazon.in/dp/B0FKP8NZCM',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/61JPOQd0bsL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 42,
#   'rank': 43,
#   'asin': 'B0FHKDFGQ6',
#   'product_title': 'Win 11 Pro win 10 pro Product License Key - 1 User Lifetime Validity (Quick Email Delivery) 32 Bit | 64 Bit',
#   'product_price': '₹345.00',
#   'product_star_rating': 3.6,
#   'product_num_ratings': 3.0,
#   'product_url': 'https://www.amazon.in/dp/B0FHKDFGQ6',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/51TO7Fe+XAL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 43,
#   'rank': 44,
#   'asin': 'B083WNLMY6',
#   'product_title': 'Guardian Antivirus Total Security With Anti-Ransomware- 1Pc/1Year (Email Delivery In 2 Hours- No Cd)',
#   'product_price': '₹330.00',
#   'product_star_rating': 4.3,
#   'product_num_ratings': 825.0,
#   'product_url': 'https://www.amazon.in/dp/B083WNLMY6',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/619FeGlgOyL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 44,
#   'rank': 45,
#   'asin': 'B0FDX9WHJN',
#   'product_title': 'TECHLOCKER Win 11 Pro Online License Key Motherboard Bind (1 User/PC, Lifetime Validity) 32/64 Bit | Unlimited Reinstallation',
#   'product_price': '₹949.00',
#   'product_star_rating': 5.0,
#   'product_num_ratings': 34.0,
#   'product_url': 'https://www.amazon.in/dp/B0FDX9WHJN',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/61NWkJkn9NL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 45,
#   'rank': 46,
#   'asin': 'B085LHBMJD',
#   'product_title': 'Net Protector Antivirus Pro 2025 - 1 PC 1 Year, (Email delivery in 1 Hour- No CD)',
#   'product_price': '₹280.00',
#   'product_star_rating': 4.2,
#   'product_num_ratings': 921.0,
#   'product_url': 'https://www.amazon.in/dp/B085LHBMJD',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/71xUzoOXVYL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 46,
#   'rank': 47,
#   'asin': 'B0DQQ3TFQB',
#   'product_title': 'Quick Heal Total Security Latest Version for Android - 1 Device, 3 Years Email Delivery In 1 Hour- No Cd',
#   'product_price': '₹329.00',
#   'product_star_rating': 4.1,
#   'product_num_ratings': 76.0,
#   'product_url': 'https://www.amazon.in/dp/B0DQQ3TFQB',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/61X7UiQdo8L._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 47,
#   'rank': 48,
#   'asin': 'B09J52FGYY',
#   'product_title': 'Apple - App Store Code - For India - Delivered via Email',
#   'product_price': '₹10,000.00',
#   'product_star_rating': 2.7,
#   'product_num_ratings': 28.0,
#   'product_url': 'https://www.amazon.in/dp/B09J52FGYY',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/61oGeVY8LjL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 48,
#   'rank': 49,
#   'asin': 'B0FKNSMZ1C',
#   'product_title': 'Win 11 & 10 Pro Retail Product License Key (Latest 2025 Edition) (1 User/PC, Lifetime Validity) 32/64 bit | Unlimited Reinsta',
#   'product_price': '₹899.00',
#   'product_star_rating': 5.0,
#   'product_num_ratings': 5.0,
#   'product_url': 'https://www.amazon.in/dp/B0FKNSMZ1C',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/61JY6u0f8GL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 49,
#   'rank': 50,
#   'asin': 'B07KCDBL3Q',
#   'product_title': "K7 Security K7 Total Security Latest Version, 3 Pc's, 1 Year (Email Delivery In 2 Hours, No Cd)",
#   'product_price': '₹725.00',
#   'product_star_rating': 4.2,
#   'product_num_ratings': 1137.0,
#   'product_url': 'https://www.amazon.in/dp/B07KCDBL3Q',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/51Naj0jsuZL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  {'Unnamed: 0': 50,
#   'rank': 51,
#   'asin': 'B088GG3DPG',
#   'product_title': 'Kaspersky | Internet Security | 1 Device | 3 Years | Email Delivery in 1 Hour',
#   'product_price': '₹849.00',
#   'product_star_rating': 4.5,
#   'product_num_ratings': 3304.0,
#   'product_url': 'https://www.amazon.in/dp/B088GG3DPG',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/61twIGQHstL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 2},
#  {'Unnamed: 0': 51,
#   'rank': 52,
#   'asin': 'B088GD41DY',
#   'product_title': 'Kaspersky Standard Security 2025 | 1 Device | 1 Year | Email Delivery in 1 Hour',
#   'product_price': '₹299.00',
#   'product_star_rating': 4.3,
#   'product_num_ratings': 454.0,
#   'product_url': 'https://www.amazon.in/dp/B088GD41DY',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/71YwFe8Ox3L._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 2},
#  {'Unnamed: 0': 52,
#   'rank': 53,
#   'asin': 'B07CMYRGMH',
#   'product_title': 'Npav | Net Protector | Total Security | Latest Version | 1 Pc | 1 Year | Email Delivery In 1 Hour - No Cd',
#   'product_price': '₹399.00',
#   'product_star_rating': 4.2,
#   'product_num_ratings': 2533.0,
#   'product_url': 'https://www.amazon.in/dp/B07CMYRGMH',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/81S2rMgfqhL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 2},
#  {'Unnamed: 0': 53,
#   'rank': 54,
#   'asin': 'B0CG9JML21',
#   'product_title': 'Bitdefender 3 Device, 1 Year - Total Mobile Security | Android & iOS | Latest Version |(Single Activation Code) - [Email Deli',
#   'product_price': '₹253.00',
#   'product_star_rating': 4.2,
#   'product_num_ratings': 140.0,
#   'product_url': 'https://www.amazon.in/dp/B0CG9JML21',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/811zSOpydOL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 2},
#  {'Unnamed: 0': 54,
#   'rank': 55,
#   'asin': 'B0CR6KQ8TF',
#   'product_title': 'Bitdefender - 1 Device,1 Year - Mobile Security | Android | Latest Version | Email Delivery in 2 Hours- No CD |',
#   'product_price': '₹94.00',
#   'product_star_rating': 4.4,
#   'product_num_ratings': 963.0,
#   'product_url': 'https://www.amazon.in/dp/B0CR6KQ8TF',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/71M1HiAgbbL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 2},
#  {'Unnamed: 0': 55,
#   'rank': 56,
#   'asin': 'B0DPQ2R9SD',
#   'product_title': 'Microsoft Office Home 2024 - Lifetime Validity - Email Delivery in 3 hours',
#   'product_price': '₹7,738.00',
#   'product_star_rating': 4.5,
#   'product_num_ratings': 75.0,
#   'product_url': 'https://www.amazon.in/dp/B0DPQ2R9SD',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/61WwdEbasFL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 2},
#  {'Unnamed: 0': 56,
#   'rank': 57,
#   'asin': 'B0DQPYGCGV',
#   'product_title': 'Quick Heal | Antivirus Pro – Renewal Pack | 1 user | 1 Years | Email Delivery in 1 Hour - no CD | Existing Quick Heal Single ',
#   'product_price': '₹395.00',
#   'product_star_rating': 3.8,
#   'product_num_ratings': 37.0,
#   'product_url': 'https://www.amazon.in/dp/B0DQPYGCGV',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/61jWpystTTL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 2},
#  {'Unnamed: 0': 57,
#   'rank': 58,
#   'asin': 'B0FM42F66T',
#   'product_title': 'Ms Home 2024 for MacOS (New 2025 Updated Edition) | Lifetime License for all Mac (Supports M1, M2, M3, M4) | Pre-Activated | ',
#   'product_price': '₹2,399.00',
#   'product_star_rating': 5.0,
#   'product_num_ratings': 2.0,
#   'product_url': 'https://www.amazon.in/dp/B0FM42F66T',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/61Xg4zlHiOL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 2},
#  {'Unnamed: 0': 58,
#   'rank': 59,
#   'asin': 'B07PS3XFSH',
#   'product_title': 'Norton Mobile Security - 1 Device - 1 Year (Email Delivery in 2 Hours - No CD)',
#   'product_price': '₹199.00',
#   'product_star_rating': 4.1,
#   'product_num_ratings': 130.0,
#   'product_url': 'https://www.amazon.in/dp/B07PS3XFSH',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/81Gp6p83Q3L._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 2},
#  {'Unnamed: 0': 59,
#   'rank': 60,
#   'asin': 'B0D4VHZ6BZ',
#   'product_title': 'McAfee Total Protection 2024 | 3 Devices, 2 Years | Antivirus Internet Security Software | Password Manager & Dark Web Monito',
#   'product_price': '₹1,899.00',
#   'product_star_rating': 4.4,
#   'product_num_ratings': 53.0,
#   'product_url': 'https://www.amazon.in/dp/B0D4VHZ6BZ',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/71vI9BNCWVL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 2},
#  {'Unnamed: 0': 60,
#   'rank': 61,
#   'asin': 'B073VMC9S1',
#   'product_title': 'Quick Heal Total Security - 2 PCs, 1 Year | AI Based Device Security for Windows PC | Banking and Browsing Protection | Dark ',
#   'product_price': '₹1,463.00',
#   'product_star_rating': 4.4,
#   'product_num_ratings': 14912.0,
#   'product_url': 'https://www.amazon.in/dp/B073VMC9S1',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/61UYfvsgWZL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 2},
#  {'Unnamed: 0': 61,
#   'rank': 62,
#   'asin': 'B073VJYH6X',
#   'product_title': 'Quick Heal Antivirus Pro Latest Version - 2 PCs, 1 Year | AI Based Device Security for Laptop | Email and Browsing Protection',
#   'product_price': '₹669.00',
#   'product_star_rating': 4.3,
#   'product_num_ratings': 12850.0,
#   'product_url': 'https://www.amazon.in/dp/B073VJYH6X',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/61JvzucNPuL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 2},
#  {'Unnamed: 0': 62,
#   'rank': 63,
#   'asin': 'B086XT4BH2',
#   'product_title': 'Norton 360 Standard |1 User 3 Year|Total Security For Pc,Mac, Android Or Ios |Additionally Includes Password Manager, Pc Clou',
#   'product_price': '₹1,499.00',
#   'product_star_rating': 4.2,
#   'product_num_ratings': 2668.0,
#   'product_url': 'https://www.amazon.in/dp/B086XT4BH2',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/61cx1hVm7nL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 2},
#  {'Unnamed: 0': 63,
#   'rank': 64,
#   'asin': 'B07CBWJSVS',
#   'product_title': 'K7 Security K7, Total Security, 1 User, 13 Months, Email Delivery In 2 Hours, No Cd',
#   'product_price': '₹395.00',
#   'product_star_rating': 4.2,
#   'product_num_ratings': 6054.0,
#   'product_url': 'https://www.amazon.in/dp/B07CBWJSVS',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/61i7FgSfhxL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 2},
#  {'Unnamed: 0': 64,
#   'rank': 65,
#   'asin': 'B073VKKNN6',
#   'product_title': 'Quick Heal Antivirus Pro Latest Version - 2 PCs, 3 Years | AI Based Device Security for Laptop | Email and Browsing Protectio',
#   'product_price': '₹1,327.00',
#   'product_star_rating': 4.3,
#   'product_num_ratings': 12850.0,
#   'product_url': 'https://www.amazon.in/dp/B073VKKNN6',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/61sNcI+zmvL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 2},
#  {'Unnamed: 0': 65,
#   'rank': 66,
#   'asin': 'B096BLH25W',
#   'product_title': 'Norton Antivirus Plus | 1 User 3 Years |Additionally Includes Smart Firewall, Password Manager & PC Cloud Back Up | PC & Mac ',
#   'product_price': '₹879.00',
#   'product_star_rating': 4.2,
#   'product_num_ratings': 679.0,
#   'product_url': 'https://www.amazon.in/dp/B096BLH25W',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/713WbmKSugL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 2},
#  {'Unnamed: 0': 66,
#   'rank': 67,
#   'asin': 'B0DKNFNW86',
#   'product_title': "CCleaner Professional for Windows | 1 Device 3 Year | Boost your PC's performance | Email Delivery in 2 hours.",
#   'product_price': '₹379.00',
#   'product_star_rating': 4.3,
#   'product_num_ratings': 27.0,
#   'product_url': 'https://www.amazon.in/dp/B0DKNFNW86',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/61nzXHsG9RL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 2},
#  {'Unnamed: 0': 67,
#   'rank': 68,
#   'asin': 'B0FC35Y4G3',
#   'product_title': 'TECHLOCKER MSO Professional Plus 2021 Retail Lifetime License Key Only & Updates | Phone Offline Activation | For Win 10 or 1',
#   'product_price': '₹949.00',
#   'product_star_rating': 4.9,
#   'product_num_ratings': 14.0,
#   'product_url': 'https://www.amazon.in/dp/B0FC35Y4G3',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/51wtP-pHhuL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 2},
#  {'Unnamed: 0': 68,
#   'rank': 69,
#   'asin': 'B0C3W45MWD',
#   'product_title': 'Kaspersky | Premium - Total Security (Ultimate Security) | 3 Devices | 3 Years | Email Delivery in 1 Hour',
#   'product_price': '₹2,299.00',
#   'product_star_rating': 4.4,
#   'product_num_ratings': 105.0,
#   'product_url': 'https://www.amazon.in/dp/B0C3W45MWD',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/71wvxMSor0L._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 2},
#  {'Unnamed: 0': 69,
#   'rank': 70,
#   'asin': 'B07B8MLKTP',
#   'product_title': 'Bitdefender - 1 Computer,3 Years - Antivirus Plus | Windows | Latest Version | Email Delivery in 2 Hours- No CD |',
#   'product_price': '₹379.00',
#   'product_star_rating': 3.9,
#   'product_num_ratings': 4180.0,
#   'product_url': 'https://www.amazon.in/dp/B07B8MLKTP',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/81zvL6zv8oL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 2},
#  {'Unnamed: 0': 70,
#   'rank': 71,
#   'asin': 'B0FLYGYYJX',
#   'product_title': 'MS 2021 Professional Plus Edition | (1 User) Retail License Key | Lifetime Validity for Windows PC | New Version | Lifetime R',
#   'product_price': '₹1,599.00',
#   'product_star_rating': 5.0,
#   'product_num_ratings': 2.0,
#   'product_url': 'https://www.amazon.in/dp/B0FLYGYYJX',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/51c1GeDsTZL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 2},
#  {'Unnamed: 0': 71,
#   'rank': 72,
#   'asin': 'B07CHMP7J1',
#   'product_title': 'NPAV | Net Protector | Total Security | Latest Version | 1 PC | 3 Years | Email Delivery in 1 Hour - No CD',
#   'product_price': '₹999.00',
#   'product_star_rating': 4.3,
#   'product_num_ratings': 699.0,
#   'product_url': 'https://www.amazon.in/dp/B07CHMP7J1',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/81k9lkANjBL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 2},
#  {'Unnamed: 0': 72,
#   'rank': 73,
#   'asin': 'B07FN8GFQP',
#   'product_title': 'eScan Anti-Virus with Total Protection Version 11 - 1 PC, 1 Year (Email Delivery in 2 Hours - No CD)',
#   'product_price': '₹175.00',
#   'product_star_rating': 4.1,
#   'product_num_ratings': 789.0,
#   'product_url': 'https://www.amazon.in/dp/B07FN8GFQP',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/71aM5iFICmL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 2},
#  {'Unnamed: 0': 73,
#   'rank': 74,
#   'asin': 'B0FF4JVYDQ',
#   'product_title': 'Kaspersky Premium Security 2025 | 1 Device | 1 Year | Digital Download | Email Delivery - No CD',
#   'product_price': '₹398.00',
#   'product_star_rating': 4.5,
#   'product_num_ratings': 2.0,
#   'product_url': 'https://www.amazon.in/dp/B0FF4JVYDQ',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/71EYvXOy8KL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 2},
#  {'Unnamed: 0': 74,
#   'rank': 75,
#   'asin': 'B0FJSC2Y8P',
#   'product_title': 'AutoCAD (2026) with Ai Software 5-Year Official Subscription (1 User, 3 Devices) (For Windows, MacOS, Android, iOS, M1, M2, M',
#   'product_price': '₹4,899.00',
#   'product_star_rating': 4.7,
#   'product_num_ratings': 6.0,
#   'product_url': 'https://www.amazon.in/dp/B0FJSC2Y8P',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/61JLttY5TqL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 2},
#  {'Unnamed: 0': 75,
#   'rank': 76,
#   'asin': 'B01AJGAAHW',
#   'product_title': 'Quick Heal | Total Security | Latest Version | 2 Users | 3 Years (Physical Box)',
#   'product_price': '₹2,679.00',
#   'product_star_rating': 4.3,
#   'product_num_ratings': 5650.0,
#   'product_url': 'https://www.amazon.in/dp/B01AJGAAHW',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/51lncpsguRL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 2},
#  {'Unnamed: 0': 76,
#   'rank': 77,
#   'asin': 'B0FM49Z24X',
#   'product_title': 'MS 365 Enterprise Copilot Edition with Chat Gpt 5.0 intergrated in Apps | New 2025 Exclusive Edition | (5 Devices, Lifetime V',
#   'product_price': '₹3,299.00',
#   'product_star_rating': 5.0,
#   'product_num_ratings': 3.0,
#   'product_url': 'https://www.amazon.in/dp/B0FM49Z24X',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/71iZsXshhOL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 2},
#  {'Unnamed: 0': 77,
#   'rank': 78,
#   'asin': 'B079KPY3H6',
#   'product_title': 'ESET Home Security Essential (Internet Security) 1 User, 1 Year (Email Delivery - No CD)',
#   'product_price': '₹500.00',
#   'product_star_rating': 4.5,
#   'product_num_ratings': 1695.0,
#   'product_url': 'https://www.amazon.in/dp/B079KPY3H6',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/81N092Nr5aL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 2},
#  {'Unnamed: 0': 78,
#   'rank': 79,
#   'asin': 'B073VJYG4Q',
#   'product_title': 'Kaspersky Plus Security 2025 | 1 Device | 1 Year | Email Delivery in 1 Hour',
#   'product_price': '₹399.00',
#   'product_star_rating': 4.1,
#   'product_num_ratings': 2288.0,
#   'product_url': 'https://www.amazon.in/dp/B073VJYG4Q',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/71XcwZ6p4nL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 2},
#  {'Unnamed: 0': 79,
#   'rank': 80,
#   'asin': 'B0DQQ534GS',
#   'product_title': 'Quick Heal Total Security Latest Version for Android - 1 Device, 1 Year (Email Delivery In 1 Hour- No CD)',
#   'product_price': '₹179.00',
#   'product_star_rating': 4.1,
#   'product_num_ratings': 63.0,
#   'product_url': 'https://www.amazon.in/dp/B0DQQ534GS',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/611aEoC959L._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 2},
#  {'Unnamed: 0': 80,
#   'rank': 81,
#   'asin': 'B08XC58PBG',
#   'product_title': 'K7 Ultimate Security Infiniti Antivirus 2025| Lifetime Validity, 5 Devices|Threat Protection,Internet Security,Data Backup,Mo',
#   'product_price': '₹2,971.00',
#   'product_star_rating': 4.3,
#   'product_num_ratings': 649.0,
#   'product_url': 'https://www.amazon.in/dp/B08XC58PBG',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/71uYMkAXucL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 2},
#  {'Unnamed: 0': 81,
#   'rank': 82,
#   'asin': 'B0BWS96MGV',
#   'product_title': 'Kaspersky | Anti-Virus | 1 Device | 2 Years | Email Delivery in 1 Hour',
#   'product_price': '₹500.00',
#   'product_star_rating': 4.5,
#   'product_num_ratings': 81.0,
#   'product_url': 'https://www.amazon.in/dp/B0BWS96MGV',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/61Gx-p-aosL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 2},
#  {'Unnamed: 0': 82,
#   'rank': 83,
#   'asin': 'B0CQR8C43D',
#   'product_title': 'K7 Security K7 Antivirus Premium 1 Device 3 Years, Powered By MAT (Artificial Intelligence), Smart Firewall, Real-time Protec',
#   'product_price': '₹498.00',
#   'product_star_rating': 4.2,
#   'product_num_ratings': 123.0,
#   'product_url': 'https://www.amazon.in/dp/B0CQR8C43D',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/61SGGiU0g5L._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 2},
#  {'Unnamed: 0': 83,
#   'rank': 84,
#   'asin': 'B07VCHY568',
#   'product_title': 'McAfee Internet Security 2025 | 1 Device, 1 Year | Antivirus Internet Security Software | Email Delivery',
#   'product_price': '₹499.00',
#   'product_star_rating': 4.2,
#   'product_num_ratings': 457.0,
#   'product_url': 'https://www.amazon.in/dp/B07VCHY568',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/61Qb7L6d84L._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 2},
#  {'Unnamed: 0': 84,
#   'rank': 85,
#   'asin': 'B07BMWRFTT',
#   'product_title': 'Bitdefender - 5 Devices,3 Years - Total Security | Windows| Mac| Android|iOS | Latest Version |(Single Activation Code) Email',
#   'product_price': '₹1,960.00',
#   'product_star_rating': 4.3,
#   'product_num_ratings': 395.0,
#   'product_url': 'https://www.amazon.in/dp/B07BMWRFTT',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/81DQwt4jV+L._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 2},
#  {'Unnamed: 0': 85,
#   'rank': 86,
#   'asin': 'B07DSXB3ZG',
#   'product_title': 'Guardian Total Security 1 User 1 Year',
#   'product_price': '₹330.00',
#   'product_star_rating': 4.4,
#   'product_num_ratings': 830.0,
#   'product_url': 'https://www.amazon.in/dp/B07DSXB3ZG',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/61GreXDPYtL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 2},
#  {'Unnamed: 0': 86,
#   'rank': 87,
#   'asin': 'B07C81JC3S',
#   'product_title': 'Eset Mobile Security for Android Latest Version - 1 Device, 1 Year (Email Delivery in 2 Hours - No CD)',
#   'product_price': '₹160.00',
#   'product_star_rating': 4.3,
#   'product_num_ratings': 600.0,
#   'product_url': 'https://www.amazon.in/dp/B07C81JC3S',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/71pBp7t83YL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 2},
#  {'Unnamed: 0': 87,
#   'rank': 88,
#   'asin': 'B0FHBJV4NC',
#   'product_title': 'Win 10 Pro Product License Key - 1 User Lifetime Validity One Pc (Quick Email Delivery)',
#   'product_price': '₹347.00',
#   'product_star_rating': 3.6,
#   'product_num_ratings': 3.0,
#   'product_url': 'https://www.amazon.in/dp/B0FHBJV4NC',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/51XBiJMn+hL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 2},
#  {'Unnamed: 0': 88,
#   'rank': 89,
#   'asin': 'B0DKNNQBP9',
#   'product_title': 'CCleaner Professional Plus| 3 Devices 3 Years | Windows PC, Mac & Android | Boost your device performance | Email Delivery in',
#   'product_price': '₹899.00',
#   'product_star_rating': 4.5,
#   'product_num_ratings': 36.0,
#   'product_url': 'https://www.amazon.in/dp/B0DKNNQBP9',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/614P11eKWgL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 2},
#  {'Unnamed: 0': 89,
#   'rank': 90,
#   'asin': 'B073VKWTZG',
#   'product_title': 'Kaspersky Standard Security 2025 | 1 Device | 1 Year | Digital Download | Instant Delivery - No CD',
#   'product_price': '₹301.00',
#   'product_star_rating': 4.3,
#   'product_num_ratings': 8536.0,
#   'product_url': 'https://www.amazon.in/dp/B073VKWTZG',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/71M+Mklp+fL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 2},
#  {'Unnamed: 0': 90,
#   'rank': 91,
#   'asin': 'B0DQPZ8YV6',
#   'product_title': 'Quick Heal | Antivirus Pro | 1 user | 3 Years | AI Based Device Security for Laptop | Email and Browsing Protection (Email De',
#   'product_price': '₹1,133.00',
#   'product_star_rating': 5.0,
#   'product_num_ratings': 6.0,
#   'product_url': 'https://www.amazon.in/dp/B0DQPZ8YV6',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/61jm+YZTgbL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 2},
#  {'Unnamed: 0': 91,
#   'rank': 92,
#   'asin': 'B0FK3M92F3',
#   'product_title': 'Ms Home Full Suite 2024 for MacOS (Latest 2026 Updated Edition) | Lifetime License for all Mac (Supports M1, M2, M3, M4) | Pr',
#   'product_price': '₹2,199.00',
#   'product_star_rating': 4.0,
#   'product_num_ratings': 5.0,
#   'product_url': 'https://www.amazon.in/dp/B0FK3M92F3',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/61xUDeIgPrL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 2},
#  {'Unnamed: 0': 92,
#   'rank': 93,
#   'asin': 'B07C7YTHYD',
#   'product_title': 'NPAV | Net Protector | Anti-Virus Pro | Latest Version | 1 PC | 1 Year | Email Delivery in 1 Hour - No CD',
#   'product_price': '₹280.00',
#   'product_star_rating': 4.0,
#   'product_num_ratings': 1157.0,
#   'product_url': 'https://www.amazon.in/dp/B07C7YTHYD',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/81uCf1cwJDL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 2},
#  {'Unnamed: 0': 93,
#   'rank': 94,
#   'asin': 'B0F67LM1M7',
#   'product_title': 'Microsoft 365 Family – 6 Users- up to 6 TB of cloud storage (1 TB per person)- Advanced security - Innovative apps with AI - ',
#   'product_price': '₹7,279.00',
#   'product_star_rating': 4.8,
#   'product_num_ratings': 6.0,
#   'product_url': 'https://www.amazon.in/dp/B0F67LM1M7',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/51+kv4pT4pL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 2},
#  {'Unnamed: 0': 94,
#   'rank': 95,
#   'asin': 'B086N1TZKP',
#   'product_title': 'Norton 360 Deluxe |3 Users 3 Years|Total Security for PC, Mac, Android or iOS|Additionally Includes Password Manager,PC Cloud',
#   'product_price': '₹2,459.00',
#   'product_star_rating': 4.6,
#   'product_num_ratings': 133.0,
#   'product_url': 'https://www.amazon.in/dp/B086N1TZKP',
# ...
#   'asin': 'B0D7MDZF5L',
#   'product_title': '初音ミク V4X (incl. ENGLISH)',
#   'product_price': '$2,704.18',
#   'product_star_rating': 4.1,
#   'product_num_ratings': 24.0,
#   'product_url': 'https://www.amazon.com.mx/dp/B0D7MDZF5L',
#   'product_photo': 'https://images-na.ssl-images-amazon.com/images/I/61K8qqqxvDL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'MX',
#   'page': 2},
#  {'Unnamed: 0': 968,
#   'rank': 70,
#   'asin': 'B0CH442XW8',
#   'product_title': 'Video Editing Software Pack | Editor, YouTube Downloader, MP3 MP4 Converter, Green Screen App | 10K Transitions for Premiere ',
#   'product_price': None,
#   'product_star_rating': 3.6,
#   'product_num_ratings': 138.0,
#   'product_url': 'https://www.amazon.com.mx/dp/B0CH442XW8',
#   'product_photo': 'https://images-na.ssl-images-amazon.com/images/I/8167JbjZ1IL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'MX',
#   'page': 2},
#  {'Unnamed: 0': 969,
#   'rank': 71,
#   'asin': 'B0BXSW6WN7',
#   'product_title': 'Wondershare Filmora 12 | WIN | 1 Gerät | (Product Keycard) Lebenslange Lizenz | Aktivierungscode per Post',
#   'product_price': '$1,994.40',
#   'product_star_rating': 4.4,
#   'product_num_ratings': 20.0,
#   'product_url': 'https://www.amazon.com.mx/dp/B0BXSW6WN7',
#   'product_photo': 'https://images-na.ssl-images-amazon.com/images/I/61vNSvpiszL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'MX',
#   'page': 2},
#  {'Unnamed: 0': 970,
#   'rank': 72,
#   'asin': 'B0C3Y5K4JB',
#   'product_title': 'VMware Workstation 17 Pro, Lifetime, 1 Device',
#   'product_price': None,
#   'product_star_rating': 5.0,
#   'product_num_ratings': 1.0,
#   'product_url': 'https://www.amazon.com.mx/dp/B0C3Y5K4JB',
#   'product_photo': 'https://images-na.ssl-images-amazon.com/images/I/51RMRiOk2mL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'MX',
#   'page': 2},
#  {'Unnamed: 0': 971,
#   'rank': 73,
#   'asin': 'B0DTQG2G6D',
#   'product_title': 'Laplink PCmover Ultimate 11 - Migration of your Applications, Files and Settings from an Old PC to a New PC - Data Transfer S',
#   'product_price': '$1,861.66',
#   'product_star_rating': 5.0,
#   'product_num_ratings': 9.0,
#   'product_url': 'https://www.amazon.com.mx/dp/B0DTQG2G6D',
#   'product_photo': 'https://images-na.ssl-images-amazon.com/images/I/71P81UsTozL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'MX',
#   'page': 2},
#  {'Unnamed: 0': 972,
#   'rank': 74,
#   'asin': 'B0BJ9N5RMP',
#   'product_title': 'Tech-Shop-pro Reinstall USB with key For Windows 11 Pro Version 32/64 bit. Recover, Restore, Repair Boot Disc, and Install to',
#   'product_price': '$1,246.64',
#   'product_star_rating': 4.0,
#   'product_num_ratings': 126.0,
#   'product_url': 'https://www.amazon.com.mx/dp/B0BJ9N5RMP',
#   'product_photo': 'https://images-na.ssl-images-amazon.com/images/I/71o2cLW+ZOL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'MX',
#   'page': 2},
#  {'Unnamed: 0': 973,
#   'rank': 75,
#   'asin': 'B06WP73RDN',
#   'product_title': 'GIMP Editor de Fotos 2025: Software de edición de imágenes Premium y profesional en CD compatible con Windows 11, 10, 8, 7, V',
#   'product_price': '$399.99',
#   'product_star_rating': 3.4,
#   'product_num_ratings': 769.0,
#   'product_url': 'https://www.amazon.com.mx/dp/B06WP73RDN',
#   'product_photo': 'https://images-na.ssl-images-amazon.com/images/I/61Mw9zor+ML._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'MX',
#   'page': 2},
#  {'Unnamed: 0': 974,
#   'rank': 76,
#   'asin': 'B00X6H7CCI',
#   'product_title': 'Spectrasonics Omnisphere 2 - Software de edición de audio/música',
#   'product_price': '$10,818.58',
#   'product_star_rating': 4.7,
#   'product_num_ratings': 218.0,
#   'product_url': 'https://www.amazon.com.mx/dp/B00X6H7CCI',
#   'product_photo': 'https://images-na.ssl-images-amazon.com/images/I/61B7etJsMJL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'MX',
#   'page': 2},
#  {'Unnamed: 0': 975,
#   'rank': 77,
#   'asin': 'B09DH2LCX5',
#   'product_title': 'Microsoft Office - Hogar y Empresa - 1 Dispositivo - 1 Usuario - PC/Mac | Código por mail',
#   'product_price': None,
#   'product_star_rating': 4.7,
#   'product_num_ratings': 113.0,
#   'product_url': 'https://www.amazon.com.mx/dp/B09DH2LCX5',
#   'product_photo': 'https://images-na.ssl-images-amazon.com/images/I/51N5g03fNEL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'MX',
#   'page': 2},
#  {'Unnamed: 0': 976,
#   'rank': 78,
#   'asin': 'B0C5J1GQ95',
#   'product_title': 'Microsoft Office 2021 Professional Plus Edition │ Lifetime │ Windows 10/11',
#   'product_price': None,
#   'product_star_rating': 4.0,
#   'product_num_ratings': 49.0,
#   'product_url': 'https://www.amazon.com.mx/dp/B0C5J1GQ95',
#   'product_photo': 'https://images-na.ssl-images-amazon.com/images/I/517Am6AxGnL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'MX',
#   'page': 2},
#  {'Unnamed: 0': 977,
#   'rank': 79,
#   'asin': 'B0C7RPCLJ3',
#   'product_title': 'The Crew Motorfest - Standard Edition, Xbox One',
#   'product_price': '$760.64',
#   'product_star_rating': 4.5,
#   'product_num_ratings': 105.0,
#   'product_url': 'https://www.amazon.com.mx/dp/B0C7RPCLJ3',
#   'product_photo': 'https://images-na.ssl-images-amazon.com/images/I/81zhadTaPQL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'MX',
#   'page': 2},
#  {'Unnamed: 0': 978,
#   'rank': 80,
#   'asin': 'B0C7SPYJ11',
#   'product_title': 'AudioDeluxe Bundle FL Studio 21 Producer Edition and Waves Musicians 2',
#   'product_price': '$4,110.65',
#   'product_star_rating': 4.6,
#   'product_num_ratings': 62.0,
#   'product_url': 'https://www.amazon.com.mx/dp/B0C7SPYJ11',
#   'product_photo': 'https://images-na.ssl-images-amazon.com/images/I/71-aGxaeKtL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'MX',
#   'page': 2},
#  {'Unnamed: 0': 979,
#   'rank': 81,
#   'asin': 'B0BMKGNDK8',
#   'product_title': 'IBM SPSS Statistics Grad Pack Premium V29.0 12 Month License for 2 Computers',
#   'product_price': '$3,995.79',
#   'product_star_rating': 3.2,
#   'product_num_ratings': 4.0,
#   'product_url': 'https://www.amazon.com.mx/dp/B0BMKGNDK8',
#   'product_photo': 'https://images-na.ssl-images-amazon.com/images/I/41dSA5q410L._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'MX',
#   'page': 2},
#  {'Unnamed: 0': 980,
#   'rank': 82,
#   'asin': 'B0DJPY6SDT',
#   'product_title': 'Microsoft Office Home and Business 2024 | Compra única | Antes Office Home & Bussiness 2021 [Código Digital]',
#   'product_price': '$6,859.00',
#   'product_star_rating': 1.0,
#   'product_num_ratings': 1.0,
#   'product_url': 'https://www.amazon.com.mx/dp/B0DJPY6SDT',
#   'product_photo': 'https://images-na.ssl-images-amazon.com/images/I/61XVXAnJodL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'MX',
#   'page': 2},
#  {'Unnamed: 0': 981,
#   'rank': 83,
#   'asin': 'B07ZLGQYPQ',
#   'product_title': 'Ralix Windows Emergency Boot Disk - For Windows 98, 2000, XP, Vista, 7, 10 PC Repair DVD All in One Tool (Latest Version)',
#   'product_price': None,
#   'product_star_rating': 3.3,
#   'product_num_ratings': 2354.0,
#   'product_url': 'https://www.amazon.com.mx/dp/B07ZLGQYPQ',
#   'product_photo': 'https://images-na.ssl-images-amazon.com/images/I/810-f3AMQCL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'MX',
#   'page': 2},
#  {'Unnamed: 0': 982,
#   'rank': 84,
#   'asin': 'B0CQCNQ4N4',
#   'product_title': 'Server 2022 Standard 64 bit | 16 core',
#   'product_price': '$2,445.80',
#   'product_star_rating': 4.6,
#   'product_num_ratings': 13.0,
#   'product_url': 'https://www.amazon.com.mx/dp/B0CQCNQ4N4',
#   'product_photo': 'https://images-na.ssl-images-amazon.com/images/I/31Eom8PWFSL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'MX',
#   'page': 2},
#  {'Unnamed: 0': 983,
#   'rank': 85,
#   'asin': 'B08NHJGL51',
#   'product_title': 'GIMP Photo Editor 2025 Compatible con Adobe Photoshop Elements CC CS6 CS5 15. Software de edición de imágenes Premium y profe',
#   'product_price': '$399.99',
#   'product_star_rating': 3.5,
#   'product_num_ratings': 105.0,
#   'product_url': 'https://www.amazon.com.mx/dp/B08NHJGL51',
#   'product_photo': 'https://images-na.ssl-images-amazon.com/images/I/61MJKv0QZhL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'MX',
#   'page': 2},
#  {'Unnamed: 0': 984,
#   'rank': 86,
#   'asin': 'B0001GU8PA',
#   'product_title': 'TP-LINK CPE210 - Punto de Acceso (300 Megabit por Segundo, 2.4 Gigahertz, 300 Megabit por Segundo, TDMA, 2 Texto, 128-bit WEP',
#   'product_price': '$910.78',
#   'product_star_rating': 4.4,
#   'product_num_ratings': 6.0,
#   'product_url': 'https://www.amazon.com.mx/dp/B0001GU8PA',
#   'product_photo': 'https://images-na.ssl-images-amazon.com/images/I/21c-i5z5g2L._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'MX',
#   'page': 2},
#  {'Unnamed: 0': 985,
#   'rank': 87,
#   'asin': 'B0DZY2B6ML',
#   'product_title': 'PDF Pro 4 - incl. OCR - sign PDFs - create forms - edit, convert, comment, create - for Win 11, 10, 8.1, 7',
#   'product_price': '$1,438.21',
#   'product_star_rating': 2.8,
#   'product_num_ratings': 6.0,
#   'product_url': 'https://www.amazon.com.mx/dp/B0DZY2B6ML',
#   'product_photo': 'https://images-na.ssl-images-amazon.com/images/I/71DKFnyODAL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'MX',
#   'page': 2},
#  {'Unnamed: 0': 986,
#   'rank': 88,
#   'asin': 'B09THG8QYM',
#   'product_title': 'PDF Pro 3 - PDF editor to create, edit and convert PDFs - 100% Compatible with Adobe Acrobat – software for Windows 11, 10, 8',
#   'product_price': '$1,117.11',
#   'product_star_rating': 3.5,
#   'product_num_ratings': 174.0,
#   'product_url': 'https://www.amazon.com.mx/dp/B09THG8QYM',
#   'product_photo': 'https://images-na.ssl-images-amazon.com/images/I/71gZFWFajQL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'MX',
#   'page': 2},
#  {'Unnamed: 0': 987,
#   'rank': 89,
#   'asin': 'B0BSLVRRV8',
#   'product_title': 'Yamaha AG 08 Mezclador de transmisión en vivo de 8 canales',
#   'product_price': '$12,450.21',
#   'product_star_rating': 3.4,
#   'product_num_ratings': 9.0,
#   'product_url': 'https://www.amazon.com.mx/dp/B0BSLVRRV8',
#   'product_photo': 'https://images-na.ssl-images-amazon.com/images/I/71HshabpBDL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'MX',
#   'page': 2},
#  {'Unnamed: 0': 988,
#   'rank': 90,
#   'asin': 'B010MIN9A2',
#   'product_title': 'ClearClick VHS to DVD Wizard Software with USB Video Capture Device',
#   'product_price': '$719.95',
#   'product_star_rating': 4.0,
#   'product_num_ratings': 1373.0,
#   'product_url': 'https://www.amazon.com.mx/dp/B010MIN9A2',
#   'product_photo': 'https://images-na.ssl-images-amazon.com/images/I/91qxZmD2l6L._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'MX',
#   'page': 2},
#  {'Unnamed: 0': 989,
#   'rank': 91,
#   'asin': 'B00NW2ZJB8',
#   'product_title': 'Nuance Dragon USB Headset',
#   'product_price': None,
#   'product_star_rating': 4.0,
#   'product_num_ratings': 718.0,
#   'product_url': 'https://www.amazon.com.mx/dp/B00NW2ZJB8',
#   'product_photo': 'https://images-na.ssl-images-amazon.com/images/I/41lhVQMBi4L._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'MX',
#   'page': 2},
#  {'Unnamed: 0': 990,
#   'rank': 92,
#   'asin': 'B0CJYL7JYV',
#   'product_title': 'TurboTax Deluxe 2023 Tax Software, Federal & State Tax Return [Amazon Exclusive] [PC/MAC Disc]',
#   'product_price': None,
#   'product_star_rating': 4.6,
#   'product_num_ratings': 6407.0,
#   'product_url': 'https://www.amazon.com.mx/dp/B0CJYL7JYV',
#   'product_photo': 'https://images-na.ssl-images-amazon.com/images/I/71Eulvi6neL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'MX',
#   'page': 2},
#  {'Unnamed: 0': 991,
#   'rank': 93,
#   'asin': 'B0CM553HKF',
#   'product_title': 'Moho Debut 14 | Animation software for PC and macOS',
#   'product_price': '$1,284.49',
#   'product_star_rating': 4.1,
#   'product_num_ratings': 56.0,
#   'product_url': 'https://www.amazon.com.mx/dp/B0CM553HKF',
#   'product_photo': 'https://images-na.ssl-images-amazon.com/images/I/61KVHS896QL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'MX',
#   'page': 2},
#  {'Unnamed: 0': 992,
#   'rank': 94,
#   'asin': 'B0DYGBP3RY',
#   'product_title': 'Software Punto de Venta Sistema - 2 Licencias',
#   'product_price': '$999.00',
#   'product_star_rating': None,
#   'product_num_ratings': None,
#   'product_url': 'https://www.amazon.com.mx/dp/B0DYGBP3RY',
#   'product_photo': 'https://images-na.ssl-images-amazon.com/images/I/51+ymRxMGRL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'MX',
#   'page': 2},
#  {'Unnamed: 0': 993,
#   'rank': 95,
#   'asin': 'B0D2CZPL7T',
#   'product_title': 'CLIP STUDIO PAINT PRO - Version 3 | Perpetual License | for Windows and macOS',
#   'product_price': '$1,429.03',
#   'product_star_rating': 4.9,
#   'product_num_ratings': 15.0,
#   'product_url': 'https://www.amazon.com.mx/dp/B0D2CZPL7T',
#   'product_photo': 'https://images-na.ssl-images-amazon.com/images/I/61oi14rlgSL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'MX',
#   'page': 2},
#  {'Unnamed: 0': 994,
#   'rank': 96,
#   'asin': 'B0DP7LBGM1',
#   'product_title': 'Microsoft Windows Server 2025 Standard Edition - License - 1 User CAL',
#   'product_price': '$1,561.01',
#   'product_star_rating': None,
#   'product_num_ratings': None,
#   'product_url': 'https://www.amazon.com.mx/dp/B0DP7LBGM1',
#   'product_photo': 'https://images-na.ssl-images-amazon.com/images/I/61zs9J1kTTL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'MX',
#   'page': 2},
#  {'Unnamed: 0': 995,
#   'rank': 97,
#   'asin': 'B0CFZNMZW6',
#   'product_title': 'Photoshop Elements 2024 and Premiere Elements 2024 | Box with Download Code',
#   'product_price': '$3,067.45',
#   'product_star_rating': 4.0,
#   'product_num_ratings': 82.0,
#   'product_url': 'https://www.amazon.com.mx/dp/B0CFZNMZW6',
#   'product_photo': 'https://images-na.ssl-images-amazon.com/images/I/81CucSxYsJL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'MX',
#   'page': 2},
#  {'Unnamed: 0': 996,
#   'rank': 98,
#   'asin': 'B09H2BRVWZ',
#   'product_title': 'Microsoft Office Hogar y Empresa 2021',
#   'product_price': '$5,999.00',
#   'product_star_rating': 4.9,
#   'product_num_ratings': 12.0,
#   'product_url': 'https://www.amazon.com.mx/dp/B09H2BRVWZ',
#   'product_photo': 'https://images-na.ssl-images-amazon.com/images/I/51tidqx+NZL._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'MX',
#   'page': 2},
#  {'Unnamed: 0': 997,
#   'rank': 99,
#   'asin': 'B0C55NKHKL',
#   'product_title': 'Virtual DJ and Karaoke Studio 8, Lifetime, 1 Device',
#   'product_price': None,
#   'product_star_rating': 3.7,
#   'product_num_ratings': 3.0,
#   'product_url': 'https://www.amazon.com.mx/dp/B0C55NKHKL',
#   'product_photo': 'https://images-na.ssl-images-amazon.com/images/I/61ln3YDXU+L._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'MX',
#   'page': 2},
#  {'Unnamed: 0': 998,
#   'rank': 100,
#   'asin': 'B091KJH72X',
#   'product_title': 'Corel WordPerfect Office Home & Student 2021 | Office Suite of Word Processor, Spreadsheets & Presentation Software [PC Disc]',
#   'product_price': '$892.21',
#   'product_star_rating': 4.3,
#   'product_num_ratings': 743.0,
#   'product_url': 'https://www.amazon.com.mx/dp/B091KJH72X',
#   'product_photo': 'https://images-na.ssl-images-amazon.com/images/I/51HxhrJSCfS._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'MX',
#   'page': 2},
#  {'Unnamed: 0': 0,
#   'rank': 1,
#   'asin': 'B073VKKNN9',
#   'product_title': 'Kaspersky | Premium - Total Security (Ultimate Security) | 1 Device | 1 Year | Email Delivery in 1 Hour',
#   'product_price': '₹469.00',
#   'product_star_rating': 4.3,
#   'product_num_ratings': 13324.0,
#   'product_url': 'https://www.amazon.in/dp/B073VKKNN9',
#   'product_photo': 'https://images-eu.ssl-images-amazon.com/images/I/71wvxMSor0L._AC_UL900_SR900,600_.jpg',
#   'rank_change_label': None,
#   'country': 'IN',
#   'page': 1},
#  ...]

# %%
amazon_df['country'].unique()
# Out:
# array(['IN', 'US', 'CA', 'AU', 'DE', 'FR', 'IT', 'ES', 'JP', 'MX'],
#       dtype=object)

# %%
amazon_df.isnull().sum()
# Out:
# Unnamed: 0                0
# rank                      0
# asin                      0
# product_title             0
# product_price           540
# product_star_rating     300
# product_num_ratings     300
# product_url               0
# product_photo             0
# rank_change_label      9990
# country                   0
# page                      0
# dtype: int64

# %%
amazon_df.shape
# Out:
# (9990, 12)

# %%
# Check for duplicates
amazon_df['asin'].nunique()
# Out:
# 961

# %%
# Remove duplicates based on ASIN + country(same product in same country)
amazon_df = amazon_df.drop_duplicates(subset=['asin', 'country'])

# %%
amazon_df.shape
# Out:
# (999, 12)

# %%
# Save extracted data
amazon_df.to_csv('extracted_amazon_data.csv', index=False)

# %%
# Check data quality
amazon_df.isnull().sum()
# Out:
# Unnamed: 0               0
# rank                     0
# asin                     0
# product_title            0
# product_price           54
# product_star_rating     30
# product_num_ratings     30
# product_url              0
# product_photo            0
# rank_change_label      999
# country                  0
# page                     0
# dtype: int64

# %%
amazon_df['country'].value_counts()
# Out:
# country
# IN    100
# CA    100
# IT    100
# AU    100
# DE    100
# FR    100
# JP    100
# ES    100
# MX    100
# US     99
# Name: count, dtype: int64

# %% [markdown]
# ## Transformation

# %%
import pandas as pd
import numpy as np
import re

# %%
# Load the extracted data
amazon_df = pd.read_csv('extracted_amazon_data.csv')

# %%
amazon_df.shape
# Out:
# (999, 12)

# %%
amazon_df.head()
# Out:
#    Unnamed: 0  rank        asin  \
# 0           0     1  B073VKKNN9
# 1           1     2  B07PQZJ6Y8
# 2           2     3  B0D1KL34JM
# 3           3     4  B07B9YYLGG
# 4           4     5  B073VLGMZ4
#
#                                        product_title product_price  \
# 0  Kaspersky | Premium - Total Security (Ultimate...       ₹469.00
# 1  K7 Security K7, Total Security, 1 User, 1 Year...       ₹370.00
# 2  Microsoft Office 2021 Professional - Lifetime ...     ₹1,799.00
# 3  Bitdefender - 1 Device,1 Year - Mobile Securit...        ₹94.00
# 4  McAfee Total Protection 2025 | 1 Device, 3 Yea...     ₹1,699.00
#
#    product_star_rating  product_num_ratings  \
# 0                  4.3              13324.0
# 1                  4.4               2291.0
# 2                  4.5                388.0
# 3                  4.1               9630.0
# 4                  4.4               5783.0
#
#                            product_url  \
# 0  https://www.amazon.in/dp/B073VKKNN9
# 1  https://www.amazon.in/dp/B07PQZJ6Y8
# 2  https://www.amazon.in/dp/B0D1KL34JM
# 3  https://www.amazon.in/dp/B07B9YYLGG
# 4  https://www.amazon.in/dp/B073VLGMZ4
#
#                                        product_photo  rank_change_label  \
# 0  https://images-eu.ssl-images-amazon.com/images...                NaN
# 1  https://images-eu.ssl-images-amazon.com/images...                NaN
# 2  https://images-eu.ssl-images-amazon.com/images...                NaN
# 3  https://images-eu.ssl-images-amazon.com/images...                NaN
# 4  https://images-eu.ssl-images-amazon.com/images...                NaN
#
#   country  page
# 0      IN     1
# 1      IN     1
# 2      IN     1
# 3      IN     1
# 4      IN     1

# %%
# Drop irrelevant columns
amazon_df = amazon_df.drop(columns=['Unnamed: 0', 'rank_change_label', 'page'])

# %%
amazon_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   rank                 999 non-null    int64
#  1   asin                 999 non-null    object
#  2   product_title        999 non-null    object
#  3   product_price        945 non-null    object
#  4   product_star_rating  969 non-null    float64
#  5   product_num_ratings  969 non-null    float64
#  6   product_url          999 non-null    object
#  7   product_photo        999 non-null    object
#  8   country              999 non-null    object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 70.4+ KB

# %% [markdown]
# ### Clean `product_price` column
# Cleans `product_price` by removing currency symbols

# %%
# Clean price and extract numeric values
def clean_price(price_str):
    if pd.isna(price_str):
        return np.nan
    
    price_str = price_str.strip()

    #Handle Eurpean format: replace comma with dot for decimal
    if  '€' in price_str:
        cleaned = re.sub(r'[₹$€\xa0]', '', price_str)
        cleaned = cleaned.replace(',', '.')
    elif '￥' in price_str:
        cleaned = re.sub(r'[￥]', '', price_str)
        cleaned = cleaned.replace(',', '')
    else:
        cleaned = re.sub(r'[₹$,]', '', price_str)
        cleaned = cleaned.replace(',', '')

    try:
        return float(cleaned)
    except:
        return np.nan

# %%
amazon_df['cleaned_price'] = amazon_df['product_price'].apply(clean_price)

# %% [markdown]
# Create `price_usd` (convert to USD)

# %%
# Approximate exchange rates
exchange_rates = {
    'IN': 0.012,  # INR to USD (1 INR = 0.012 USD)
    'US': 1.0,    # USD to USD
    'UK': 1.25,   # GBP to USD
    'CA': 0.74,   # CAD to USD
    'AU': 0.66,   # AUD to USD
    'DE': 1.08,   # EUR to USD
    'FR': 1.08,   # EUR to USD
    'IT': 1.08,   # EUR to USD
    'ES': 1.08,   # EUR to USD
    'JP': 0.0067, # JPY to USD

}

# %%
def convert_to_usd(row):
    if pd.isna(row['cleaned_price']):
        return np.nan
    
    country = row['country']
    rate = exchange_rates.get(country, 1.0)
    return row['cleaned_price'] * rate
amazon_df['price_usd'] = amazon_df.apply(convert_to_usd, axis=1)

# %%
amazon_df.head()
# Out:
#    rank        asin                                      product_title  \
# 0     1  B073VKKNN9  Kaspersky | Premium - Total Security (Ultimate...
# 1     2  B07PQZJ6Y8  K7 Security K7, Total Security, 1 User, 1 Year...
# 2     3  B0D1KL34JM  Microsoft Office 2021 Professional - Lifetime ...
# 3     4  B07B9YYLGG  Bitdefender - 1 Device,1 Year - Mobile Securit...
# 4     5  B073VLGMZ4  McAfee Total Protection 2025 | 1 Device, 3 Yea...
#
#   product_price  product_star_rating  product_num_ratings  \
# 0       ₹469.00                  4.3              13324.0
# 1       ₹370.00                  4.4               2291.0
# 2     ₹1,799.00                  4.5                388.0
# 3        ₹94.00                  4.1               9630.0
# 4     ₹1,699.00                  4.4               5783.0
#
#                            product_url  \
# 0  https://www.amazon.in/dp/B073VKKNN9
# 1  https://www.amazon.in/dp/B07PQZJ6Y8
# 2  https://www.amazon.in/dp/B0D1KL34JM
# 3  https://www.amazon.in/dp/B07B9YYLGG
# 4  https://www.amazon.in/dp/B073VLGMZ4
#
#                                        product_photo country  cleaned_price  \
# 0  https://images-eu.ssl-images-amazon.com/images...      IN          469.0
# 1  https://images-eu.ssl-images-amazon.com/images...      IN          370.0
# 2  https://images-eu.ssl-images-amazon.com/images...      IN         1799.0
# 3  https://images-eu.ssl-images-amazon.com/images...      IN           94.0
# 4  https://images-eu.ssl-images-amazon.com/images...      IN         1699.0
#
#    price_usd
# 0      5.628
# 1      4.440
# 2     21.588
# 3      1.128
# 4     20.388

# %% [markdown]
# ### Create `revenue_estimate`

# %%
amazon_df['revenue_estimate'] = amazon_df['price_usd'] * amazon_df['product_num_ratings']

# %% [markdown]
# ### Create `rating_bucket`

# %%
# Categorize rating into buckets
def categorize_rating(rating):
    if pd.isna(rating):
        return 'No Rating'
    elif rating <= 2.0:
        return 'Low'
    elif rating <= 3.5:
        return 'Medium'
    elif rating <= 4.5:
        return 'High'
    else:
        return 'Excellent'
amazon_df['rating_bucket'] = amazon_df['product_star_rating'].apply(categorize_rating)

# %% [markdown]
# ### Create `review_density`

# %%
amazon_df['review_density'] = amazon_df['product_num_ratings'] / amazon_df['price_usd']
amazon_df['review_density'] = amazon_df['review_density'].replace([np.inf, -np.inf], np.nan)

# %% [markdown]
# ### Create `category` (extract from product_title)

# %%
# Extract product category from title
def extract_category(title):
    if pd.isna(title):
        return 'Other'
    
    title = title.lower()

    if any(word in title for word in ['antivirus', 'security', 'norton', 'mcafee', 'kaspersky', 'bitdefender', 'firewall']):
        return 'Security Software'
    elif any(word in title for word in ['office', 'word', 'excel', 'powerpoint', 'microsoft 365', 'ms office']):
        return 'Office Software'
    elif any(word in title for word in ['photo', 'video', 'adobe', 'photoshop', 'illustrator', 'premiere', 'lightroom']):
        return 'Creative Software'
    elif any(word in title for word in ['vpn', 'virtual private network', 'mullvad']):
        return 'VPN Software'
    elif any(word in title for word in ['cloud', 'aws', 'azure', 'google cloud', 'dropbox']):
        return 'Cloud Software'
    elif any(word in title for word in ['game', 'gaming', 'steam', 'epic games', 'origin']):
        return 'Gaming Software'
    elif any(word in title for word in ['utility', 'cleaner', 'ccleaner', 'defragment', 'disk']):
        return 'Utility Software'
    elif any(word in title for word in ['windows', 'win10', 'win11', 'ubuntu', 'macos']):
        return 'Operating System'   
    elif any(word in title for word in ['development', 'ide', 'visual studio', 'eclipse', 'pycharm', 'intellij']):  
        return 'Development Software'
    elif any(word in title for word in ['app store', 'gift card']):
        return 'Digital Credits'
    elif any(word in title for word in ['subscription', 'monthly', 'annual']):
        return 'Subscription Services'
    elif any(word in title for word in ['autocad', 'drafting', 'design']):
        return 'Design Software'
    else:
        return 'Other Software'
    
amazon_df['category'] = amazon_df['product_title'].apply(extract_category)

# %% [markdown]
# ### Create `brand` (extract from product_title)

# %%
# Extract brand from  product title
def extract_brand(title):
    if pd.isna(title):
        return 'Other'
    
    title = title.lower()

    # Check for common brands
    brands = {
        'microsoft': 'Microsoft',
        'norton': 'Norton',
        'mcafee': 'McAfee',
        'kaspersky': 'Kaspersky',
        'bitdefender': 'Bitdefender',
        'turbotax': 'TurboTax',
        'h&r block': 'H&R Block',
        'adobe': 'Adobe',
        'quick heal': 'Quick Heal',
        'webroot': 'Webroot',
        'mullvad': 'Mullvad',
        'apple': 'Apple',
        'eset': 'ESET',
        'k7': 'K7 Security'
    }

    for brand_key, brand_name in brands.items():
        if brand_key in title:
            return brand_name

    return 'Other Brand'
amazon_df['brand'] = amazon_df['product_title'].apply(extract_brand)

# %% [markdown]
# ### Create `country_region`

# %%
# Map country code to region
def map_country_to_region(country):
    regions = {
        'US': 'North America',
        'CA': 'North America',
        'UK': 'Europe',
        'DE': 'Europe',
        'FR': 'Europe',
        'IT': 'Europe',
        'ES': 'Europe',
        'IN': 'Asia',
        'JP': 'Asia',
        'AU': 'Oceania',
        'BR': 'South America',
        'MX': 'North America'
    }
    return regions.get(country, 'Other Region')
amazon_df['country_region'] = amazon_df['country'].apply(map_country_to_region)

# %%
amazon_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   rank                 999 non-null    int64
#  1   asin                 999 non-null    object
#  2   product_title        999 non-null    object
#  3   product_price        945 non-null    object
#  4   product_star_rating  969 non-null    float64
#  5   product_num_ratings  969 non-null    float64
#  6   product_url          999 non-null    object
#  7   product_photo        999 non-null    object
#  8   country              999 non-null    object
#  9   cleaned_price        945 non-null    float64
#  10  price_usd            945 non-null    float64
#  11  revenue_estimate     915 non-null    float64
#  12  rating_bucket        999 non-null    object
#  13  review_density       915 non-null    float64
#  14  category             999 non-null    object
#  15  brand                999 non-null    object
#  16  country_region       999 non-null    object
# dtypes: float64(6), int64(1), object(10)
# memory usage: 132.8+ KB

# %% [markdown]
# ### Handling missing values

# %%
amazon_df.isnull().sum()
# Out:
# rank                    0
# asin                    0
# product_title           0
# product_price          54
# product_star_rating    30
# product_num_ratings    30
# product_url             0
# product_photo           0
# country                 0
# cleaned_price          54
# price_usd              54
# revenue_estimate       84
# rating_bucket           0
# review_density         84
# category                0
# brand                   0
# country_region          0
# dtype: int64

# %%
# Fill missing product_star_rating with median by category
amazon_df['product_star_rating'] = amazon_df.groupby('category')['product_star_rating'].transform(lambda x: x.fillna(x.median()))

# %%
# Fill missing num_ratings with median by category
amazon_df['product_num_ratings'] = amazon_df.groupby('category')['product_num_ratings'].transform(lambda x: x.fillna(x.median()))

# %%
# Recalculate derived variables after filling missing values
amazon_df['revenue_estimate'] = amazon_df['price_usd'] * amazon_df['product_num_ratings']
amazon_df['review_density'] = amazon_df['product_num_ratings'] / amazon_df['price_usd']
amazon_df['review_density'] = amazon_df['review_density'].replace([np.inf, -np.inf], np.nan)
amazon_df['rating_bucket'] = amazon_df['product_star_rating'].apply(categorize_rating)

# %% [markdown]
# ### Transformation Summarry

# %%
# Final shape
amazon_df.shape
# Out:
# (999, 17)

# %%
# Missing values after cleaning
amazon_df.isnull().sum()
# Out:
# rank                    0
# asin                    0
# product_title           0
# product_price          54
# product_star_rating     0
# product_num_ratings     0
# product_url             0
# product_photo           0
# country                 0
# cleaned_price          54
# price_usd              54
# revenue_estimate       54
# rating_bucket           0
# review_density         54
# category                0
# brand                   0
# country_region          0
# dtype: int64

# %%
# Check problematic prices
print("Sample of missing price_usd where product_price exists:")
mask = amazon_df['price_usd'].isna() & amazon_df['product_price'].notna()
print(amazon_df[mask]['product_price'].head(10).tolist())
# Out:
# Sample of missing price_usd where product_price exists:
# []

# %%
# Save transformed data
amazon_df.to_csv('transformed_amazon_data.csv', index=False)

# %% [markdown]
# ### Loading

# %%
from sqlalchemy import create_engine
import psycopg2

# %%
# Load transformed data
amazon_df = pd.read_csv('transformed_amazon_data.csv')
print(f"Loading {amazon_df.shape[0]} records to PostgreSQL database")
# Out:
# Loading 999 records to PostgreSQL database

# %%
# Database connection 
conn_string = 'postgresql://avnadmin:AVNS_dkpx47HSLApO3Wbk3-J@pg-204f0187-os679736-e1d8.c.aivencloud.com:22022/defaultdb?sslmode=require'
engine = create_engine(conn_string)

# %%
# Load data into PostgreSQL
amazon_df.to_sql('amazon_data', engine, if_exists='replace', index=False)
# Out:
# 999

# %%
# Verify the load
verification_query = """ 
SELECT 
    COUNT(*) as total_records,
    COUNT(DISTINCT country) as unique_countries,
    COUNT(DISTINCT category) as unique_categories,
    COUNT(DISTINCT brand) as unique_brands,
    AVG(price_usd) as avg_price_usd,
    AVG(product_star_rating) as avg_rating
FROM amazon_data
WHERE price_usd IS NOT NULL;
"""
result = pd.read_sql(verification_query, engine)

# %%
result.head()
# Out:
#    total_records  unique_countries  unique_categories  unique_brands  \
# 0            945                10                 12             15
#
#    avg_price_usd  avg_rating
# 0     235.445672    4.136878
